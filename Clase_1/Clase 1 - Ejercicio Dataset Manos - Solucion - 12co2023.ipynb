# %% [markdown]
# # Ejercicio Data Augmentation
#
# En este ejercicio se utilizará el dataset de manos, en el cual hay imágenes de 64x64 pixeles a color divididas en 6 clases, cada una representando un número distinto (0, 1, 2, 3, 4 o 5) indicado con los dedos de la mano.
#
# El conjunto de entrenamiento fue modificado de forma tal que el mismo sobreentrene una red neuronal convolucional si no se aplica ningún tipo de data augmentation. Dentro de la carpeta `train/` se encuentran 6 carpetas, cada una con 30 imágenes. El conjunto de validación no fue modificado. El mismo se encuentra en la carpeta `valid/` con 20 imágenes en cada clase.
#
# El objetivo de este ejercicio es, entonces, realizar entrenamientos de una misma arquitectura de red convolucional, utilizando data augmentation para obtener la mejor performance posible.

# %%
# !pip install torchmetrics
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.1.1-py3-none-any.whl (763 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.4/763.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.23.5)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.0.1+cu118)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.9.0 torchmetrics-1.1.1
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# Successfully installed gdown-4.7.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import os

import torch
import torchvision
import torchsummary
import torchmetrics
from torch.utils.tensorboard import SummaryWriter

# %%
# !gdown 1e0bdIt_uCaTof7i57-O7XZ-wPy15nikT
# !unzip dataset_manos_modificado.zip > /dev/null
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1e0bdIt_uCaTof7i57-O7XZ-wPy15nikT
# To: /content/dataset_manos_modificado.zip
# 100% 1.60M/1.60M [00:00<00:00, 47.0MB/s]

# %% [markdown]
# ### Visualización de los datos
#
# Con la siguiente celda de código podemos visualizar una imagen de cada clase, tomada al azar, del conjunto de entrenamiento. Siempre es importante tener nocion de como lucen las imágenes de nuestro set de datos, tanto de entrenamiento como validación. Esto nos ayudará a saber que tipos de transformaciones serán más útiles cuando realicemos data augmentation.

# %%
train_folder = './dataset_manos_modificado/train/'

fig, axs = plt.subplots(1, 6, figsize=(20, 20))

for id, class_folder in enumerate(sorted(os.listdir(train_folder))):

    image_name = random.choice(os.listdir(os.path.join(train_folder, class_folder)))
    image = mpimg.imread(os.path.join(train_folder, class_folder, image_name))

    axs[id].imshow(image)
    axs[id].set_title(class_folder)

# %% [markdown]
# ### Definimos nuestra función de entrenamiento

# %%
def train(model, optimizer, criterion, metric, data, epochs, tb_writer=None):

    train_loader = data["train"]
    valid_loader = data["valid"]

    train_writer = tb_writer["train"]
    valid_writer = tb_writer["valid"]

    if tb_writer:
        train_writer.add_graph(model, torch.zeros((1, 3, data["image_width"], data["image_height"])))
        valid_writer.add_graph(model, torch.zeros((1, 3, data["image_width"], data["image_height"])))

    if torch.cuda.is_available():
        model.to("cuda")
        metric.to("cuda")

    train_loss = []
    train_acc = []
    valid_loss = []
    valid_acc = []

    for epoch in range(epochs):

        # Pongo el modelo en modo entrenamiento
        model.train()

        epoch_train_loss = 0.0
        epoch_train_accuracy = 0.0

        for train_data, train_target in train_loader:

            if torch.cuda.is_available():
                train_data.to("cuda")
                train_target.to("cuda")

            optimizer.zero_grad()
            output = model(train_data.float())
            loss = criterion(output, train_target)
            epoch_train_loss += loss.item()
            loss.backward()
            optimizer.step()

            accuracy = metric(output, train_target)
            epoch_train_accuracy += accuracy.item()

        epoch_train_loss = epoch_train_loss / len(train_loader)
        epoch_train_accuracy = epoch_train_accuracy / len(train_loader)
        train_loss.append(epoch_train_loss)
        train_acc.append(epoch_train_accuracy)

        # Pongo el modelo en modo testeo
        model.eval()

        epoch_valid_loss = 0.0
        epoch_valid_accuracy = 0.0

        for valid_data, valid_target in valid_loader:
            if torch.cuda.is_available():
                valid_data.to("cuda")
                valid_target.to("cuda")

            output = model(valid_data.float())
            epoch_valid_loss += criterion(output, valid_target).item()
            epoch_valid_accuracy += metric(output, valid_target).item()

        epoch_valid_loss = epoch_valid_loss / len(valid_loader)
        epoch_valid_accuracy = epoch_valid_accuracy / len(valid_loader)
        valid_loss.append(epoch_valid_loss)
        valid_acc.append(epoch_valid_accuracy)

        print("Epoch: {}/{} - Train loss {:.6f} - Train Accuracy {:.6f} - Valid Loss {:.6f} - Valid Accuracy {:.6f}".format(
        epoch+1, epochs, epoch_train_loss, epoch_train_accuracy, epoch_valid_loss, epoch_valid_accuracy))

        if tb_writer:
            train_writer.add_scalar("loss", epoch_train_loss, epoch)
            valid_writer.add_scalar("loss", epoch_valid_loss, epoch)
            train_writer.add_scalar("accuracy", epoch_train_accuracy, epoch)
            valid_writer.add_scalar("accuracy", epoch_valid_accuracy, epoch)
            train_writer.flush()
            valid_writer.flush()

    history = {}
    history["train_loss"] = train_loss
    history["train_acc"] = train_acc
    history["valid_loss"] = valid_loss
    history["valid_acc"] = valid_acc

    return history

# %% [markdown]
# ### Definimos nuestra arquitectura de red neuronal
#
# En la siguiente celda se define una clase para una red neuronal convolucional con 4 capas convolucionales, cada una seguida de un max pooling. Luego del último bloque convolucional-pooling se realiza un flatten y se agregan 2 capas densas para la clasificación.
#
# Para que esta celda funcione se debe completar el valor de `in_features` de la primera capa densa, el cual se puede calcular sabiendo el tamaño de las imágenes de entrada a la red, y cómo afecta cada capa convolucional y de pooling a las dimensión del tensor de entrada de dicha capa densa.

# %%
CANTIDAD_CLASES = 6
ANCHO_IMAGENES = 64
ALTO_IMAGENES = 64

# %%
class ConvModel(torch.nn.Module):
    def __init__(self, output_units):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding='same')
        self.pool1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = torch.nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding='same')
        self.pool2 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = torch.nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding='same')
        self.pool3 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv4 = torch.nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding='same')
        self.pool4 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = torch.nn.Linear(in_features=2048, out_features=512)
        self.fc2 = torch.nn.Linear(in_features=512, out_features=output_units)

    def forward(self, x):
        x = self.pool1(torch.relu(self.conv1(x)))
        x = self.pool2(torch.relu(self.conv2(x)))
        x = self.pool3(torch.relu(self.conv3(x)))
        x = self.pool4(torch.relu(self.conv4(x)))
        x = torch.flatten(x, 1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

conv_model = ConvModel(CANTIDAD_CLASES)

# Si hay una GPU disponible muevo el modelo allí para aprovechar ese recurso
if torch.cuda.is_available():
    conv_model.to("cuda")

torchsummary.summary(conv_model, (3, ANCHO_IMAGENES, ALTO_IMAGENES))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 64, 64]             448
#          MaxPool2d-2           [-1, 16, 32, 32]               0
#             Conv2d-3           [-1, 32, 32, 32]           4,640
#          MaxPool2d-4           [-1, 32, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]          18,496
#          MaxPool2d-6             [-1, 64, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]          73,856
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Linear-9                  [-1, 512]       1,049,088
#            Linear-10                    [-1, 6]           3,078
# ================================================================
# Total params: 1,149,606
# Trainable params: 1,149,606
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 1.18
# Params size (MB): 4.39
# Estimated Total Size (MB): 5.61
# ----------------------------------------------------------------

# %% [markdown]
# ### 1) Entrenar sin aplicar Data Augmentation
#
# En primer lugar se define una composición de transformaciones que no realice ninguna modificación sobre las imágenes más que pasarlas a tensores, como lo pide torchvision. Luego se definen los `DataLoaders` para el entrenamiento.

# %%
data_transforms = torchvision.transforms.Compose([
                    torchvision.transforms.ToTensor(),
                  ])

train_set = torchvision.datasets.ImageFolder(root='./dataset_manos_modificado/train', transform=data_transforms)
valid_set = torchvision.datasets.ImageFolder(root='./dataset_manos_modificado/valid', transform=data_transforms)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size=32, shuffle=True)

# %% [markdown]
# Realizar el entrenamiento de la red durante 30 épocas y observar el sobreentrenamiento que se genera en el modelo.

# %%
noaug_conv_model = ConvModel(CANTIDAD_CLASES)
noaug_optimizer = torch.optim.Adam(noaug_conv_model.parameters(), lr=0.001)
noaug_loss = torch.nn.CrossEntropyLoss()
noaug_metric = torchmetrics.Accuracy(task='multiclass', num_classes=CANTIDAD_CLASES)
noaug_data = {"train": train_loader, "valid": valid_loader, "image_width": ANCHO_IMAGENES, "image_height": ALTO_IMAGENES}

noaug_writer = {"train": SummaryWriter(log_dir="data_aug/noaug_train"),
                "valid": SummaryWriter(log_dir="data_aug/noaug_valid")}

history = train(noaug_conv_model,
                noaug_optimizer,
                noaug_loss,
                noaug_metric,
                noaug_data,
                30,
                noaug_writer)

fig, axs = plt.subplots(2, 1, figsize=(10, 10))

axs[0].plot(history["train_loss"])
axs[0].plot(history["valid_loss"])
axs[0].title.set_text('Error de Entrenamiento vs Validación')
axs[0].legend(['Train', 'Valid'])

axs[1].plot(history["train_acc"])
axs[1].plot(history["valid_acc"])
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación')
axs[1].legend(['Train', 'Valid'])
# Out:
# Epoch: 1/30 - Train loss 1.803502 - Train Accuracy 0.138021 - Valid Loss 1.791707 - Valid Accuracy 0.164062
# Epoch: 2/30 - Train loss 1.792112 - Train Accuracy 0.166667 - Valid Loss 1.791621 - Valid Accuracy 0.169271
# Epoch: 3/30 - Train loss 1.792024 - Train Accuracy 0.130208 - Valid Loss 1.790979 - Valid Accuracy 0.169271
# Epoch: 4/30 - Train loss 1.791393 - Train Accuracy 0.182292 - Valid Loss 1.790443 - Valid Accuracy 0.315104
# Epoch: 5/30 - Train loss 1.790143 - Train Accuracy 0.286458 - Valid Loss 1.788832 - Valid Accuracy 0.382812
# Epoch: 6/30 - Train loss 1.787669 - Train Accuracy 0.294271 - Valid Loss 1.785018 - Valid Accuracy 0.229167
# Epoch: 7/30 - Train loss 1.783164 - Train Accuracy 0.247396 - Valid Loss 1.774731 - Valid Accuracy 0.273438
# Epoch: 8/30 - Train loss 1.776414 - Train Accuracy 0.268229 - Valid Loss 1.755852 - Valid Accuracy 0.231771
# Epoch: 9/30 - Train loss 1.741825 - Train Accuracy 0.289062 - Valid Loss 1.758343 - Valid Accuracy 0.242188
# Epoch: 10/30 - Train loss 1.720511 - Train Accuracy 0.273438 - Valid Loss 1.709313 - Valid Accuracy 0.239583
# Epoch: 11/30 - Train loss 1.670818 - Train Accuracy 0.309896 - Valid Loss 1.645361 - Valid Accuracy 0.242188
# Epoch: 12/30 - Train loss 1.635018 - Train Accuracy 0.338542 - Valid Loss 1.535992 - Valid Accuracy 0.338542
# Epoch: 13/30 - Train loss 1.489861 - Train Accuracy 0.403646 - Valid Loss 1.525474 - Valid Accuracy 0.354167
# Epoch: 14/30 - Train loss 1.376620 - Train Accuracy 0.450521 - Valid Loss 1.381309 - Valid Accuracy 0.395833
# Epoch: 15/30 - Train loss 1.236178 - Train Accuracy 0.518229 - Valid Loss 1.356390 - Valid Accuracy 0.442708
# Epoch: 16/30 - Train loss 1.209035 - Train Accuracy 0.575521 - Valid Loss 1.260041 - Valid Accuracy 0.434896
# Epoch: 17/30 - Train loss 1.102556 - Train Accuracy 0.585938 - Valid Loss 1.211468 - Valid Accuracy 0.463542
# Epoch: 18/30 - Train loss 0.982938 - Train Accuracy 0.588542 - Valid Loss 1.291276 - Valid Accuracy 0.481771
# Epoch: 19/30 - Train loss 0.929457 - Train Accuracy 0.651042 - Valid Loss 1.129082 - Valid Accuracy 0.515625
# Epoch: 20/30 - Train loss 0.796591 - Train Accuracy 0.705729 - Valid Loss 1.100682 - Valid Accuracy 0.565104
# Epoch: 21/30 - Train loss 0.734843 - Train Accuracy 0.690104 - Valid Loss 1.091566 - Valid Accuracy 0.554688
# Epoch: 22/30 - Train loss 0.662098 - Train Accuracy 0.760417 - Valid Loss 1.028546 - Valid Accuracy 0.585938
# Epoch: 23/30 - Train loss 0.526674 - Train Accuracy 0.812500 - Valid Loss 1.365082 - Valid Accuracy 0.494792
# Epoch: 24/30 - Train loss 0.708945 - Train Accuracy 0.744792 - Valid Loss 1.596636 - Valid Accuracy 0.476562
# Epoch: 25/30 - Train loss 0.756517 - Train Accuracy 0.679688 - Valid Loss 1.364651 - Valid Accuracy 0.570312
# Epoch: 26/30 - Train loss 0.579672 - Train Accuracy 0.757812 - Valid Loss 1.065075 - Valid Accuracy 0.638021
# Epoch: 27/30 - Train loss 0.529484 - Train Accuracy 0.820312 - Valid Loss 1.065323 - Valid Accuracy 0.614583
# Epoch: 28/30 - Train loss 0.362116 - Train Accuracy 0.872396 - Valid Loss 1.019992 - Valid Accuracy 0.625000
# Epoch: 29/30 - Train loss 0.306176 - Train Accuracy 0.893229 - Valid Loss 0.967400 - Valid Accuracy 0.703125
# Epoch: 30/30 - Train loss 0.281276 - Train Accuracy 0.911458 - Valid Loss 1.087709 - Valid Accuracy 0.622396

# %% [markdown]
# ---
# ### 2) Entrenar aplicando Data Augmentation
#
# A continuación se define una composición de transformaciones para aplicar data augmentation sobre el conjunto de entrenamiento.
#
# Ejecutar la celda para entrenar durante, al menos, 100 épocas y analizar los resultados.

# %%
aug_data_transforms = torchvision.transforms.Compose([
                        torchvision.transforms.RandomHorizontalFlip(0.5),
                        torchvision.transforms.RandomResizedCrop(size=(64, 64), scale=(0.2, 0.7)),
                        torchvision.transforms.RandomRotation(degrees=90),
                        torchvision.transforms.RandomPerspective(0.8),
                        torchvision.transforms.RandomGrayscale(0.5),
                        torchvision.transforms.ToTensor(),
                      ])

aug_train_set = torchvision.datasets.ImageFolder(root='./dataset_manos_modificado/train', transform=aug_data_transforms)

aug_train_loader = torch.utils.data.DataLoader(aug_train_set, batch_size=32, shuffle=True)

# %%
aug_conv_model = ConvModel(CANTIDAD_CLASES)
aug_optimizer = torch.optim.Adam(aug_conv_model.parameters(), lr=0.001)
aug_loss = torch.nn.CrossEntropyLoss()
aug_metric = torchmetrics.Accuracy(task='multiclass', num_classes=CANTIDAD_CLASES)
aug_data = {"train": aug_train_loader, "valid": valid_loader, "image_width": ANCHO_IMAGENES, "image_height": ALTO_IMAGENES}

aug_writer = {"train": SummaryWriter(log_dir="data_aug/aug_train"),
              "valid": SummaryWriter(log_dir="data_aug/aug_valid")}

history = train(aug_conv_model,
                aug_optimizer,
                aug_loss,
                aug_metric,
                aug_data,
                100,
                aug_writer)

fig, axs = plt.subplots(2, 1, figsize=(10, 10))

axs[0].plot(history["train_loss"])
axs[0].plot(history["valid_loss"])
axs[0].title.set_text('Error de Entrenamiento vs Validación')
axs[0].legend(['Train', 'Valid'])

axs[1].plot(history["train_acc"])
axs[1].plot(history["valid_acc"])
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación')
axs[1].legend(['Train', 'Valid'])
# Out:
# Epoch: 1/100 - Train loss 1.801969 - Train Accuracy 0.109375 - Valid Loss 1.792378 - Valid Accuracy 0.166667
# Epoch: 2/100 - Train loss 1.793600 - Train Accuracy 0.161458 - Valid Loss 1.791999 - Valid Accuracy 0.158854
# Epoch: 3/100 - Train loss 1.792769 - Train Accuracy 0.166667 - Valid Loss 1.792754 - Valid Accuracy 0.158854
# Epoch: 4/100 - Train loss 1.792383 - Train Accuracy 0.164062 - Valid Loss 1.791936 - Valid Accuracy 0.171875
# Epoch: 5/100 - Train loss 1.792170 - Train Accuracy 0.169271 - Valid Loss 1.792093 - Valid Accuracy 0.166667
# Epoch: 6/100 - Train loss 1.791956 - Train Accuracy 0.171875 - Valid Loss 1.791859 - Valid Accuracy 0.161458
# Epoch: 7/100 - Train loss 1.792032 - Train Accuracy 0.166667 - Valid Loss 1.791785 - Valid Accuracy 0.171875
# Epoch: 8/100 - Train loss 1.792284 - Train Accuracy 0.171875 - Valid Loss 1.791673 - Valid Accuracy 0.164062
# Epoch: 9/100 - Train loss 1.791973 - Train Accuracy 0.171875 - Valid Loss 1.791792 - Valid Accuracy 0.174479
# Epoch: 10/100 - Train loss 1.792001 - Train Accuracy 0.161458 - Valid Loss 1.792051 - Valid Accuracy 0.158854
# Epoch: 11/100 - Train loss 1.792491 - Train Accuracy 0.161458 - Valid Loss 1.792297 - Valid Accuracy 0.161458
# Epoch: 12/100 - Train loss 1.792092 - Train Accuracy 0.171875 - Valid Loss 1.791886 - Valid Accuracy 0.164062
# Epoch: 13/100 - Train loss 1.791909 - Train Accuracy 0.164062 - Valid Loss 1.791712 - Valid Accuracy 0.169271
# Epoch: 14/100 - Train loss 1.792243 - Train Accuracy 0.161458 - Valid Loss 1.791946 - Valid Accuracy 0.164062
# Epoch: 15/100 - Train loss 1.791847 - Train Accuracy 0.179688 - Valid Loss 1.791760 - Valid Accuracy 0.164062
# Epoch: 16/100 - Train loss 1.791887 - Train Accuracy 0.127604 - Valid Loss 1.791781 - Valid Accuracy 0.169271
# Epoch: 17/100 - Train loss 1.792125 - Train Accuracy 0.161458 - Valid Loss 1.791850 - Valid Accuracy 0.164062
# Epoch: 18/100 - Train loss 1.791747 - Train Accuracy 0.229167 - Valid Loss 1.791751 - Valid Accuracy 0.161458
# Epoch: 19/100 - Train loss 1.791950 - Train Accuracy 0.148438 - Valid Loss 1.791795 - Valid Accuracy 0.164062
# Epoch: 20/100 - Train loss 1.792469 - Train Accuracy 0.122396 - Valid Loss 1.791764 - Valid Accuracy 0.169271
# Epoch: 21/100 - Train loss 1.792420 - Train Accuracy 0.148438 - Valid Loss 1.791742 - Valid Accuracy 0.158854
# Epoch: 22/100 - Train loss 1.792562 - Train Accuracy 0.164062 - Valid Loss 1.791616 - Valid Accuracy 0.169271
# Epoch: 23/100 - Train loss 1.791226 - Train Accuracy 0.210938 - Valid Loss 1.791817 - Valid Accuracy 0.171875
# Epoch: 24/100 - Train loss 1.792912 - Train Accuracy 0.111979 - Valid Loss 1.791618 - Valid Accuracy 0.260417
# Epoch: 25/100 - Train loss 1.792759 - Train Accuracy 0.114583 - Valid Loss 1.791826 - Valid Accuracy 0.161458
# Epoch: 26/100 - Train loss 1.792157 - Train Accuracy 0.140625 - Valid Loss 1.791709 - Valid Accuracy 0.166667
# Epoch: 27/100 - Train loss 1.791650 - Train Accuracy 0.205729 - Valid Loss 1.791700 - Valid Accuracy 0.161458
# Epoch: 28/100 - Train loss 1.791818 - Train Accuracy 0.187500 - Valid Loss 1.791604 - Valid Accuracy 0.158854
# Epoch: 29/100 - Train loss 1.792261 - Train Accuracy 0.088542 - Valid Loss 1.791451 - Valid Accuracy 0.166667
# Epoch: 30/100 - Train loss 1.792149 - Train Accuracy 0.187500 - Valid Loss 1.791328 - Valid Accuracy 0.247396
# Epoch: 31/100 - Train loss 1.792202 - Train Accuracy 0.130208 - Valid Loss 1.791602 - Valid Accuracy 0.164062
# Epoch: 32/100 - Train loss 1.791833 - Train Accuracy 0.145833 - Valid Loss 1.791508 - Valid Accuracy 0.166667
# Epoch: 33/100 - Train loss 1.791665 - Train Accuracy 0.182292 - Valid Loss 1.791350 - Valid Accuracy 0.161458
# Epoch: 34/100 - Train loss 1.791471 - Train Accuracy 0.242188 - Valid Loss 1.791105 - Valid Accuracy 0.148438
# Epoch: 35/100 - Train loss 1.792600 - Train Accuracy 0.177083 - Valid Loss 1.790877 - Valid Accuracy 0.268229
# Epoch: 36/100 - Train loss 1.794726 - Train Accuracy 0.184896 - Valid Loss 1.790588 - Valid Accuracy 0.223958
# Epoch: 37/100 - Train loss 1.792237 - Train Accuracy 0.174479 - Valid Loss 1.791281 - Valid Accuracy 0.158854
# Epoch: 38/100 - Train loss 1.791601 - Train Accuracy 0.140625 - Valid Loss 1.791192 - Valid Accuracy 0.164062
# Epoch: 39/100 - Train loss 1.791234 - Train Accuracy 0.174479 - Valid Loss 1.792430 - Valid Accuracy 0.158854
# Epoch: 40/100 - Train loss 1.791987 - Train Accuracy 0.166667 - Valid Loss 1.791583 - Valid Accuracy 0.169271
# Epoch: 41/100 - Train loss 1.793587 - Train Accuracy 0.166667 - Valid Loss 1.791030 - Valid Accuracy 0.177083
# Epoch: 42/100 - Train loss 1.792282 - Train Accuracy 0.158854 - Valid Loss 1.791127 - Valid Accuracy 0.166667
# Epoch: 43/100 - Train loss 1.791625 - Train Accuracy 0.174479 - Valid Loss 1.790754 - Valid Accuracy 0.171875
# Epoch: 44/100 - Train loss 1.792102 - Train Accuracy 0.138021 - Valid Loss 1.790647 - Valid Accuracy 0.166667
# Epoch: 45/100 - Train loss 1.791481 - Train Accuracy 0.192708 - Valid Loss 1.790324 - Valid Accuracy 0.221354
# Epoch: 46/100 - Train loss 1.791385 - Train Accuracy 0.184896 - Valid Loss 1.789075 - Valid Accuracy 0.273438
# Epoch: 47/100 - Train loss 1.791432 - Train Accuracy 0.203125 - Valid Loss 1.791209 - Valid Accuracy 0.161458
# Epoch: 48/100 - Train loss 1.792155 - Train Accuracy 0.174479 - Valid Loss 1.790757 - Valid Accuracy 0.166667
# Epoch: 49/100 - Train loss 1.791120 - Train Accuracy 0.169271 - Valid Loss 1.789567 - Valid Accuracy 0.166667
# Epoch: 50/100 - Train loss 1.792702 - Train Accuracy 0.117188 - Valid Loss 1.791759 - Valid Accuracy 0.166667
# Epoch: 51/100 - Train loss 1.792092 - Train Accuracy 0.143229 - Valid Loss 1.791871 - Valid Accuracy 0.161458
# Epoch: 52/100 - Train loss 1.791936 - Train Accuracy 0.164062 - Valid Loss 1.791640 - Valid Accuracy 0.166667
# Epoch: 53/100 - Train loss 1.791907 - Train Accuracy 0.164062 - Valid Loss 1.791735 - Valid Accuracy 0.164062
# Epoch: 54/100 - Train loss 1.791962 - Train Accuracy 0.166667 - Valid Loss 1.791845 - Valid Accuracy 0.166667
# Epoch: 55/100 - Train loss 1.792042 - Train Accuracy 0.158854 - Valid Loss 1.791758 - Valid Accuracy 0.161458
# Epoch: 56/100 - Train loss 1.791805 - Train Accuracy 0.143229 - Valid Loss 1.791568 - Valid Accuracy 0.166667
# Epoch: 57/100 - Train loss 1.791966 - Train Accuracy 0.187500 - Valid Loss 1.791120 - Valid Accuracy 0.177083
# Epoch: 58/100 - Train loss 1.791793 - Train Accuracy 0.148438 - Valid Loss 1.791421 - Valid Accuracy 0.158854
# Epoch: 59/100 - Train loss 1.791552 - Train Accuracy 0.119792 - Valid Loss 1.790786 - Valid Accuracy 0.174479
# Epoch: 60/100 - Train loss 1.791064 - Train Accuracy 0.148438 - Valid Loss 1.791095 - Valid Accuracy 0.171875
# Epoch: 61/100 - Train loss 1.791363 - Train Accuracy 0.158854 - Valid Loss 1.789561 - Valid Accuracy 0.187500
# Epoch: 62/100 - Train loss 1.788860 - Train Accuracy 0.203125 - Valid Loss 1.790497 - Valid Accuracy 0.171875
# Epoch: 63/100 - Train loss 1.790744 - Train Accuracy 0.114583 - Valid Loss 1.791458 - Valid Accuracy 0.164062
# Epoch: 64/100 - Train loss 1.790533 - Train Accuracy 0.145833 - Valid Loss 1.788873 - Valid Accuracy 0.171875
# Epoch: 65/100 - Train loss 1.787967 - Train Accuracy 0.244792 - Valid Loss 1.790286 - Valid Accuracy 0.169271
# Epoch: 66/100 - Train loss 1.789213 - Train Accuracy 0.192708 - Valid Loss 1.790479 - Valid Accuracy 0.166667
# Epoch: 67/100 - Train loss 1.786551 - Train Accuracy 0.190104 - Valid Loss 1.789392 - Valid Accuracy 0.161458
# Epoch: 68/100 - Train loss 1.794154 - Train Accuracy 0.169271 - Valid Loss 1.791428 - Valid Accuracy 0.177083
# Epoch: 69/100 - Train loss 1.795182 - Train Accuracy 0.166667 - Valid Loss 1.792195 - Valid Accuracy 0.166667
# Epoch: 70/100 - Train loss 1.792523 - Train Accuracy 0.164062 - Valid Loss 1.791946 - Valid Accuracy 0.166667
# Epoch: 71/100 - Train loss 1.792086 - Train Accuracy 0.158854 - Valid Loss 1.791731 - Valid Accuracy 0.166667
# Epoch: 72/100 - Train loss 1.792158 - Train Accuracy 0.164062 - Valid Loss 1.791762 - Valid Accuracy 0.164062
# Epoch: 73/100 - Train loss 1.791887 - Train Accuracy 0.166667 - Valid Loss 1.791805 - Valid Accuracy 0.166667
# Epoch: 74/100 - Train loss 1.791891 - Train Accuracy 0.171875 - Valid Loss 1.791791 - Valid Accuracy 0.166667
# Epoch: 75/100 - Train loss 1.791919 - Train Accuracy 0.164062 - Valid Loss 1.791792 - Valid Accuracy 0.166667
# Epoch: 76/100 - Train loss 1.791941 - Train Accuracy 0.164062 - Valid Loss 1.791678 - Valid Accuracy 0.171875
# Epoch: 77/100 - Train loss 1.791866 - Train Accuracy 0.158854 - Valid Loss 1.791643 - Valid Accuracy 0.161458
# Epoch: 78/100 - Train loss 1.791951 - Train Accuracy 0.132812 - Valid Loss 1.791681 - Valid Accuracy 0.171875
# Epoch: 79/100 - Train loss 1.791871 - Train Accuracy 0.151042 - Valid Loss 1.791754 - Valid Accuracy 0.166667
# Epoch: 80/100 - Train loss 1.791789 - Train Accuracy 0.161458 - Valid Loss 1.791668 - Valid Accuracy 0.164062
# Epoch: 81/100 - Train loss 1.791912 - Train Accuracy 0.166667 - Valid Loss 1.791732 - Valid Accuracy 0.161458
# Epoch: 82/100 - Train loss 1.791893 - Train Accuracy 0.169271 - Valid Loss 1.791462 - Valid Accuracy 0.161458
# Epoch: 83/100 - Train loss 1.791974 - Train Accuracy 0.161458 - Valid Loss 1.791527 - Valid Accuracy 0.166667
# Epoch: 84/100 - Train loss 1.791839 - Train Accuracy 0.161458 - Valid Loss 1.791256 - Valid Accuracy 0.171875
# Epoch: 85/100 - Train loss 1.791668 - Train Accuracy 0.158854 - Valid Loss 1.791328 - Valid Accuracy 0.177083
# Epoch: 86/100 - Train loss 1.791325 - Train Accuracy 0.239583 - Valid Loss 1.791136 - Valid Accuracy 0.195312
# Epoch: 87/100 - Train loss 1.791557 - Train Accuracy 0.195312 - Valid Loss 1.790894 - Valid Accuracy 0.177083
# Epoch: 88/100 - Train loss 1.791585 - Train Accuracy 0.179688 - Valid Loss 1.790941 - Valid Accuracy 0.166667
# Epoch: 89/100 - Train loss 1.792301 - Train Accuracy 0.153646 - Valid Loss 1.790876 - Valid Accuracy 0.273438
# Epoch: 90/100 - Train loss 1.792039 - Train Accuracy 0.153646 - Valid Loss 1.791364 - Valid Accuracy 0.161458
# Epoch: 91/100 - Train loss 1.791489 - Train Accuracy 0.182292 - Valid Loss 1.790478 - Valid Accuracy 0.213542
# Epoch: 92/100 - Train loss 1.791611 - Train Accuracy 0.195312 - Valid Loss 1.790529 - Valid Accuracy 0.203125
# Epoch: 93/100 - Train loss 1.791204 - Train Accuracy 0.171875 - Valid Loss 1.790617 - Valid Accuracy 0.250000
# Epoch: 94/100 - Train loss 1.791812 - Train Accuracy 0.164062 - Valid Loss 1.791838 - Valid Accuracy 0.161458
# Epoch: 95/100 - Train loss 1.791733 - Train Accuracy 0.164062 - Valid Loss 1.791705 - Valid Accuracy 0.166667
# Epoch: 96/100 - Train loss 1.791840 - Train Accuracy 0.166667 - Valid Loss 1.791053 - Valid Accuracy 0.164062
# Epoch: 97/100 - Train loss 1.792859 - Train Accuracy 0.161458 - Valid Loss 1.792415 - Valid Accuracy 0.166667
# Epoch: 98/100 - Train loss 1.792643 - Train Accuracy 0.138021 - Valid Loss 1.791342 - Valid Accuracy 0.169271
# Epoch: 99/100 - Train loss 1.792383 - Train Accuracy 0.135417 - Valid Loss 1.790905 - Valid Accuracy 0.151042
# Epoch: 100/100 - Train loss 1.793367 - Train Accuracy 0.184896 - Valid Loss 1.790666 - Valid Accuracy 0.242188

# %% [markdown]
# ###**Algunas preguntas para analizar**
#
# 1) ¿Es el resultado del entrenamiento aceptable?
#
# 2) ¿Está el Data Augmentation mejorando o empeorando el resultado?
#
# 3) Basándose en las características de las imágenes del conjunto de validación, diría que el tipo de transformaciones utilizadas es acertado? (Se puede usar la celda del principio del Colab para visualizar imágenes del conjunto de validación)
#
# 4) Basándose en los resultados del entrenamiento, diría que los parámetros de las transformaciones aplicadas tienen valores agresivos? (Se puede utilizar la celda siguiente para visualizar un conjunto de imágenes y sus versiones transformadas)

# %%
# Ploteo las imagenes sin augmentacion

images_ids = np.random.randint(low=0, high=len(train_set), size=4)

fig, rows = plt.subplots(nrows=1, ncols=4, figsize=(18, 18))
for id, row in enumerate(rows):
    row.imshow(train_set[images_ids[id]][0].permute(1, 2, 0))
    row.axis('off')
plt.show()

# Ploteo las mismas imagenes con augmentacion

fig, rows = plt.subplots(nrows=1, ncols=4, figsize=(18, 18))
for id, row in enumerate(rows):
    row.imshow(aug_train_set[images_ids[id]][0].permute(1, 2, 0))
    row.axis('off')
plt.show()

# %% [markdown]
# ### 3) Mejorar/corregir el Data Augmentation
#
# En base a su criterio y a las reflexiones de las preguntas anteriores, defina una nueva composición de transformaciones que ayude a obtener buenos resultados sobre el entrenamiento. Intentar obtener métricas que superen el 90% de accuracy sin caer en sobreentrenamiento. Incrementar la cantidad de épocas de entrenamiento si es necesario.

# %%
new_aug_data_transforms = torchvision.transforms.Compose([
                            torchvision.transforms.RandomHorizontalFlip(0.5),
                            torchvision.transforms.RandomResizedCrop(size=(64, 64), scale=(0.5, 1.0)),
                            torchvision.transforms.RandomRotation(degrees=30),
                            torchvision.transforms.RandomPerspective(0.2),
                            torchvision.transforms.ToTensor(),
                        ])

new_aug_train_set = torchvision.datasets.ImageFolder(root='./dataset_manos_modificado/train', transform=new_aug_data_transforms)

new_aug_train_loader = torch.utils.data.DataLoader(new_aug_train_set, batch_size=32, shuffle=True)

# %%
new_aug_conv_model = ConvModel(CANTIDAD_CLASES)
new_aug_optimizer = torch.optim.Adam(new_aug_conv_model.parameters(), lr=0.001)
new_aug_loss = torch.nn.CrossEntropyLoss()
new_aug_metric = torchmetrics.Accuracy(task='multiclass', num_classes=CANTIDAD_CLASES)
new_aug_data = {"train": new_aug_train_loader, "valid": valid_loader, "image_width": ANCHO_IMAGENES, "image_height": ALTO_IMAGENES}

new_aug_writer = {"train": SummaryWriter(log_dir="data_aug/new_aug_train"),
                  "valid": SummaryWriter(log_dir="data_aug/new_aug_valid")}

history = train(new_aug_conv_model,
                new_aug_optimizer,
                new_aug_loss,
                new_aug_metric,
                new_aug_data,
                200,
                new_aug_writer)

fig, axs = plt.subplots(2, 1, figsize=(10, 10))

axs[0].plot(history["train_loss"])
axs[0].plot(history["valid_loss"])
axs[0].title.set_text('Error de Entrenamiento vs Validación')
axs[0].legend(['Train', 'Valid'])

axs[1].plot(history["train_acc"])
axs[1].plot(history["valid_acc"])
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación')
axs[1].legend(['Train', 'Valid'])
# Out:
# Epoch: 1/200 - Train loss 1.802635 - Train Accuracy 0.122396 - Valid Loss 1.791611 - Valid Accuracy 0.166667
# Epoch: 2/200 - Train loss 1.793057 - Train Accuracy 0.143229 - Valid Loss 1.792142 - Valid Accuracy 0.164062
# Epoch: 3/200 - Train loss 1.792013 - Train Accuracy 0.169271 - Valid Loss 1.792315 - Valid Accuracy 0.161458
# Epoch: 4/200 - Train loss 1.791834 - Train Accuracy 0.169271 - Valid Loss 1.791999 - Valid Accuracy 0.161458
# Epoch: 5/200 - Train loss 1.792102 - Train Accuracy 0.171875 - Valid Loss 1.791724 - Valid Accuracy 0.171875
# Epoch: 6/200 - Train loss 1.792166 - Train Accuracy 0.171875 - Valid Loss 1.791654 - Valid Accuracy 0.161458
# Epoch: 7/200 - Train loss 1.792481 - Train Accuracy 0.166667 - Valid Loss 1.791943 - Valid Accuracy 0.166667
# Epoch: 8/200 - Train loss 1.791947 - Train Accuracy 0.169271 - Valid Loss 1.791228 - Valid Accuracy 0.166667
# Epoch: 9/200 - Train loss 1.792095 - Train Accuracy 0.166667 - Valid Loss 1.791759 - Valid Accuracy 0.161458
# Epoch: 10/200 - Train loss 1.791436 - Train Accuracy 0.174479 - Valid Loss 1.790847 - Valid Accuracy 0.171875
# Epoch: 11/200 - Train loss 1.791135 - Train Accuracy 0.169271 - Valid Loss 1.790898 - Valid Accuracy 0.169271
# Epoch: 12/200 - Train loss 1.791356 - Train Accuracy 0.169271 - Valid Loss 1.790822 - Valid Accuracy 0.216146
# Epoch: 13/200 - Train loss 1.790823 - Train Accuracy 0.164062 - Valid Loss 1.789604 - Valid Accuracy 0.161458
# Epoch: 14/200 - Train loss 1.789670 - Train Accuracy 0.164062 - Valid Loss 1.787293 - Valid Accuracy 0.166667
# Epoch: 15/200 - Train loss 1.791631 - Train Accuracy 0.182292 - Valid Loss 1.787187 - Valid Accuracy 0.184896
# Epoch: 16/200 - Train loss 1.786227 - Train Accuracy 0.166667 - Valid Loss 1.787421 - Valid Accuracy 0.239583
# Epoch: 17/200 - Train loss 1.786731 - Train Accuracy 0.143229 - Valid Loss 1.777295 - Valid Accuracy 0.218750
# Epoch: 18/200 - Train loss 1.781186 - Train Accuracy 0.203125 - Valid Loss 1.767996 - Valid Accuracy 0.281250
# Epoch: 19/200 - Train loss 1.763021 - Train Accuracy 0.309896 - Valid Loss 1.743349 - Valid Accuracy 0.252604
# Epoch: 20/200 - Train loss 1.736611 - Train Accuracy 0.294271 - Valid Loss 1.702538 - Valid Accuracy 0.252604
# Epoch: 21/200 - Train loss 1.673269 - Train Accuracy 0.276042 - Valid Loss 1.715384 - Valid Accuracy 0.234375
# Epoch: 22/200 - Train loss 1.698408 - Train Accuracy 0.255208 - Valid Loss 1.597702 - Valid Accuracy 0.268229
# Epoch: 23/200 - Train loss 1.623976 - Train Accuracy 0.315104 - Valid Loss 1.575491 - Valid Accuracy 0.351562
# Epoch: 24/200 - Train loss 1.596120 - Train Accuracy 0.377604 - Valid Loss 1.486670 - Valid Accuracy 0.320312
# Epoch: 25/200 - Train loss 1.555774 - Train Accuracy 0.276042 - Valid Loss 1.450169 - Valid Accuracy 0.369792
# Epoch: 26/200 - Train loss 1.585603 - Train Accuracy 0.361979 - Valid Loss 1.410876 - Valid Accuracy 0.385417
# Epoch: 27/200 - Train loss 1.573903 - Train Accuracy 0.380208 - Valid Loss 1.465682 - Valid Accuracy 0.312500
# Epoch: 28/200 - Train loss 1.554636 - Train Accuracy 0.325521 - Valid Loss 1.433378 - Valid Accuracy 0.401042
# Epoch: 29/200 - Train loss 1.559326 - Train Accuracy 0.263021 - Valid Loss 1.347839 - Valid Accuracy 0.416667
# Epoch: 30/200 - Train loss 1.488630 - Train Accuracy 0.359375 - Valid Loss 1.330334 - Valid Accuracy 0.416667
# Epoch: 31/200 - Train loss 1.448147 - Train Accuracy 0.429688 - Valid Loss 1.261142 - Valid Accuracy 0.458333
# Epoch: 32/200 - Train loss 1.455121 - Train Accuracy 0.398438 - Valid Loss 1.306806 - Valid Accuracy 0.494792
# Epoch: 33/200 - Train loss 1.336288 - Train Accuracy 0.484375 - Valid Loss 1.282631 - Valid Accuracy 0.497396
# Epoch: 34/200 - Train loss 1.312189 - Train Accuracy 0.440104 - Valid Loss 1.276118 - Valid Accuracy 0.432292
# Epoch: 35/200 - Train loss 1.441885 - Train Accuracy 0.395833 - Valid Loss 1.135685 - Valid Accuracy 0.580729
# Epoch: 36/200 - Train loss 1.271257 - Train Accuracy 0.549479 - Valid Loss 1.258262 - Valid Accuracy 0.468750
# Epoch: 37/200 - Train loss 1.368431 - Train Accuracy 0.408854 - Valid Loss 1.131790 - Valid Accuracy 0.583333
# Epoch: 38/200 - Train loss 1.228215 - Train Accuracy 0.471354 - Valid Loss 1.099490 - Valid Accuracy 0.585938
# Epoch: 39/200 - Train loss 1.237311 - Train Accuracy 0.489583 - Valid Loss 1.046113 - Valid Accuracy 0.562500
# Epoch: 40/200 - Train loss 1.140163 - Train Accuracy 0.466146 - Valid Loss 0.965370 - Valid Accuracy 0.651042
# Epoch: 41/200 - Train loss 1.065377 - Train Accuracy 0.606771 - Valid Loss 0.990334 - Valid Accuracy 0.625000
# Epoch: 42/200 - Train loss 1.072601 - Train Accuracy 0.588542 - Valid Loss 0.941172 - Valid Accuracy 0.643229
# Epoch: 43/200 - Train loss 1.157988 - Train Accuracy 0.575521 - Valid Loss 0.854738 - Valid Accuracy 0.651042
# Epoch: 44/200 - Train loss 1.185187 - Train Accuracy 0.518229 - Valid Loss 0.896735 - Valid Accuracy 0.617188
# Epoch: 45/200 - Train loss 1.078626 - Train Accuracy 0.515625 - Valid Loss 0.891457 - Valid Accuracy 0.669271
# Epoch: 46/200 - Train loss 1.141386 - Train Accuracy 0.531250 - Valid Loss 0.839957 - Valid Accuracy 0.695312
# Epoch: 47/200 - Train loss 1.020041 - Train Accuracy 0.580729 - Valid Loss 0.890735 - Valid Accuracy 0.669271
# Epoch: 48/200 - Train loss 1.179679 - Train Accuracy 0.518229 - Valid Loss 0.922180 - Valid Accuracy 0.656250
# Epoch: 49/200 - Train loss 1.110747 - Train Accuracy 0.520833 - Valid Loss 0.859466 - Valid Accuracy 0.674479
# Epoch: 50/200 - Train loss 1.017305 - Train Accuracy 0.622396 - Valid Loss 0.899871 - Valid Accuracy 0.692708
# Epoch: 51/200 - Train loss 1.074076 - Train Accuracy 0.557292 - Valid Loss 0.834567 - Valid Accuracy 0.721354
# Epoch: 52/200 - Train loss 1.021846 - Train Accuracy 0.585938 - Valid Loss 0.799607 - Valid Accuracy 0.679688
# Epoch: 53/200 - Train loss 0.850211 - Train Accuracy 0.695312 - Valid Loss 0.841696 - Valid Accuracy 0.669271
# Epoch: 54/200 - Train loss 0.983225 - Train Accuracy 0.567708 - Valid Loss 0.814171 - Valid Accuracy 0.690104
# Epoch: 55/200 - Train loss 0.895693 - Train Accuracy 0.565104 - Valid Loss 0.734743 - Valid Accuracy 0.695312
# Epoch: 56/200 - Train loss 1.003313 - Train Accuracy 0.598958 - Valid Loss 1.063587 - Valid Accuracy 0.570312
# Epoch: 57/200 - Train loss 1.089426 - Train Accuracy 0.580729 - Valid Loss 0.993155 - Valid Accuracy 0.598958
# Epoch: 58/200 - Train loss 1.102240 - Train Accuracy 0.536458 - Valid Loss 0.820168 - Valid Accuracy 0.687500
# Epoch: 59/200 - Train loss 1.078229 - Train Accuracy 0.544271 - Valid Loss 0.875916 - Valid Accuracy 0.640625
# Epoch: 60/200 - Train loss 1.002662 - Train Accuracy 0.638021 - Valid Loss 0.756190 - Valid Accuracy 0.705729
# Epoch: 61/200 - Train loss 0.953771 - Train Accuracy 0.630208 - Valid Loss 0.808824 - Valid Accuracy 0.703125
# Epoch: 62/200 - Train loss 0.948124 - Train Accuracy 0.645833 - Valid Loss 0.782257 - Valid Accuracy 0.669271
# Epoch: 63/200 - Train loss 0.888037 - Train Accuracy 0.588542 - Valid Loss 0.794143 - Valid Accuracy 0.653646
# Epoch: 64/200 - Train loss 0.892935 - Train Accuracy 0.648438 - Valid Loss 0.707916 - Valid Accuracy 0.710938
# Epoch: 65/200 - Train loss 0.899500 - Train Accuracy 0.630208 - Valid Loss 0.832906 - Valid Accuracy 0.651042
# Epoch: 66/200 - Train loss 0.872757 - Train Accuracy 0.619792 - Valid Loss 0.697563 - Valid Accuracy 0.752604
# Epoch: 67/200 - Train loss 0.889363 - Train Accuracy 0.690104 - Valid Loss 0.682301 - Valid Accuracy 0.794271
# Epoch: 68/200 - Train loss 0.771742 - Train Accuracy 0.755208 - Valid Loss 0.720450 - Valid Accuracy 0.713542
# Epoch: 69/200 - Train loss 0.822982 - Train Accuracy 0.695312 - Valid Loss 0.681927 - Valid Accuracy 0.757812
# Epoch: 70/200 - Train loss 0.795988 - Train Accuracy 0.723958 - Valid Loss 0.784721 - Valid Accuracy 0.705729
# Epoch: 71/200 - Train loss 1.064468 - Train Accuracy 0.536458 - Valid Loss 0.795179 - Valid Accuracy 0.690104
# Epoch: 72/200 - Train loss 1.072860 - Train Accuracy 0.567708 - Valid Loss 0.692487 - Valid Accuracy 0.734375
# Epoch: 73/200 - Train loss 0.929863 - Train Accuracy 0.622396 - Valid Loss 0.871506 - Valid Accuracy 0.656250
# Epoch: 74/200 - Train loss 0.964618 - Train Accuracy 0.606771 - Valid Loss 0.697621 - Valid Accuracy 0.710938
# Epoch: 75/200 - Train loss 0.947691 - Train Accuracy 0.630208 - Valid Loss 0.815859 - Valid Accuracy 0.658854
# Epoch: 76/200 - Train loss 0.888910 - Train Accuracy 0.664062 - Valid Loss 0.733350 - Valid Accuracy 0.713542
# Epoch: 77/200 - Train loss 0.902967 - Train Accuracy 0.695312 - Valid Loss 0.726919 - Valid Accuracy 0.658854
# Epoch: 78/200 - Train loss 0.838789 - Train Accuracy 0.669271 - Valid Loss 0.662133 - Valid Accuracy 0.765625
# Epoch: 79/200 - Train loss 0.725866 - Train Accuracy 0.718750 - Valid Loss 0.653235 - Valid Accuracy 0.739583
# Epoch: 80/200 - Train loss 0.775059 - Train Accuracy 0.703125 - Valid Loss 0.654185 - Valid Accuracy 0.736979
# Epoch: 81/200 - Train loss 0.731020 - Train Accuracy 0.710938 - Valid Loss 0.611768 - Valid Accuracy 0.765625
# Epoch: 82/200 - Train loss 0.759443 - Train Accuracy 0.692708 - Valid Loss 0.629831 - Valid Accuracy 0.768229
# Epoch: 83/200 - Train loss 0.761354 - Train Accuracy 0.687500 - Valid Loss 0.594464 - Valid Accuracy 0.812500
# Epoch: 84/200 - Train loss 0.769815 - Train Accuracy 0.677083 - Valid Loss 0.800926 - Valid Accuracy 0.705729
# Epoch: 85/200 - Train loss 0.768124 - Train Accuracy 0.705729 - Valid Loss 0.605624 - Valid Accuracy 0.807292
# Epoch: 86/200 - Train loss 0.695936 - Train Accuracy 0.721354 - Valid Loss 0.792135 - Valid Accuracy 0.695312
# Epoch: 87/200 - Train loss 0.829023 - Train Accuracy 0.684896 - Valid Loss 0.570742 - Valid Accuracy 0.802083
# Epoch: 88/200 - Train loss 0.764083 - Train Accuracy 0.708333 - Valid Loss 0.742912 - Valid Accuracy 0.736979
# Epoch: 89/200 - Train loss 0.800434 - Train Accuracy 0.687500 - Valid Loss 0.613743 - Valid Accuracy 0.804688
# Epoch: 90/200 - Train loss 0.661193 - Train Accuracy 0.716146 - Valid Loss 0.552972 - Valid Accuracy 0.807292
# Epoch: 91/200 - Train loss 0.605958 - Train Accuracy 0.776042 - Valid Loss 0.601905 - Valid Accuracy 0.776042
# Epoch: 92/200 - Train loss 0.641304 - Train Accuracy 0.736979 - Valid Loss 0.660593 - Valid Accuracy 0.760417
# Epoch: 93/200 - Train loss 0.665058 - Train Accuracy 0.703125 - Valid Loss 0.579220 - Valid Accuracy 0.794271
# Epoch: 94/200 - Train loss 0.603498 - Train Accuracy 0.757812 - Valid Loss 0.602991 - Valid Accuracy 0.822917
# Epoch: 95/200 - Train loss 0.637360 - Train Accuracy 0.739583 - Valid Loss 0.534337 - Valid Accuracy 0.794271
# Epoch: 96/200 - Train loss 0.731017 - Train Accuracy 0.755208 - Valid Loss 0.665564 - Valid Accuracy 0.804688
# Epoch: 97/200 - Train loss 0.841880 - Train Accuracy 0.666667 - Valid Loss 0.563959 - Valid Accuracy 0.817708
# Epoch: 98/200 - Train loss 0.678507 - Train Accuracy 0.742188 - Valid Loss 0.665847 - Valid Accuracy 0.750000
# Epoch: 99/200 - Train loss 0.898883 - Train Accuracy 0.619792 - Valid Loss 0.646159 - Valid Accuracy 0.752604
# Epoch: 100/200 - Train loss 0.776193 - Train Accuracy 0.671875 - Valid Loss 0.692323 - Valid Accuracy 0.757812
# Epoch: 101/200 - Train loss 0.747576 - Train Accuracy 0.708333 - Valid Loss 0.679984 - Valid Accuracy 0.796875
# Epoch: 102/200 - Train loss 0.840148 - Train Accuracy 0.669271 - Valid Loss 0.650139 - Valid Accuracy 0.752604
# Epoch: 103/200 - Train loss 0.736134 - Train Accuracy 0.736979 - Valid Loss 0.578342 - Valid Accuracy 0.804688
# Epoch: 104/200 - Train loss 0.612539 - Train Accuracy 0.791667 - Valid Loss 0.562685 - Valid Accuracy 0.778646
# Epoch: 105/200 - Train loss 0.637655 - Train Accuracy 0.770833 - Valid Loss 0.575783 - Valid Accuracy 0.820312
# Epoch: 106/200 - Train loss 0.690423 - Train Accuracy 0.739583 - Valid Loss 0.542667 - Valid Accuracy 0.817708
# Epoch: 107/200 - Train loss 0.636353 - Train Accuracy 0.789062 - Valid Loss 0.519284 - Valid Accuracy 0.859375
# Epoch: 108/200 - Train loss 0.634730 - Train Accuracy 0.721354 - Valid Loss 0.555657 - Valid Accuracy 0.825521
# Epoch: 109/200 - Train loss 0.620720 - Train Accuracy 0.768229 - Valid Loss 0.507834 - Valid Accuracy 0.833333
# Epoch: 110/200 - Train loss 0.640149 - Train Accuracy 0.757812 - Valid Loss 0.510429 - Valid Accuracy 0.817708
# Epoch: 111/200 - Train loss 0.500845 - Train Accuracy 0.825521 - Valid Loss 0.456979 - Valid Accuracy 0.848958
# Epoch: 112/200 - Train loss 0.792886 - Train Accuracy 0.710938 - Valid Loss 0.477659 - Valid Accuracy 0.856771
# Epoch: 113/200 - Train loss 0.570583 - Train Accuracy 0.802083 - Valid Loss 0.454698 - Valid Accuracy 0.848958
# Epoch: 114/200 - Train loss 0.564487 - Train Accuracy 0.791667 - Valid Loss 0.547590 - Valid Accuracy 0.822917
# Epoch: 115/200 - Train loss 0.583664 - Train Accuracy 0.786458 - Valid Loss 0.541971 - Valid Accuracy 0.817708
# Epoch: 116/200 - Train loss 0.601476 - Train Accuracy 0.731771 - Valid Loss 0.564812 - Valid Accuracy 0.804688
# Epoch: 117/200 - Train loss 0.625350 - Train Accuracy 0.750000 - Valid Loss 0.530097 - Valid Accuracy 0.851562
# Epoch: 118/200 - Train loss 0.499033 - Train Accuracy 0.817708 - Valid Loss 0.537205 - Valid Accuracy 0.825521
# Epoch: 119/200 - Train loss 0.633736 - Train Accuracy 0.739583 - Valid Loss 0.515083 - Valid Accuracy 0.807292
# Epoch: 120/200 - Train loss 0.530808 - Train Accuracy 0.828125 - Valid Loss 0.498320 - Valid Accuracy 0.783854
# Epoch: 121/200 - Train loss 0.523889 - Train Accuracy 0.799479 - Valid Loss 0.522025 - Valid Accuracy 0.815104
# Epoch: 122/200 - Train loss 0.515103 - Train Accuracy 0.812500 - Valid Loss 0.582467 - Valid Accuracy 0.786458
# Epoch: 123/200 - Train loss 0.503791 - Train Accuracy 0.796875 - Valid Loss 0.588745 - Valid Accuracy 0.786458
# Epoch: 124/200 - Train loss 0.559270 - Train Accuracy 0.739583 - Valid Loss 0.637847 - Valid Accuracy 0.778646
# Epoch: 125/200 - Train loss 0.687535 - Train Accuracy 0.773438 - Valid Loss 0.668113 - Valid Accuracy 0.744792
# Epoch: 126/200 - Train loss 0.499701 - Train Accuracy 0.817708 - Valid Loss 0.523634 - Valid Accuracy 0.841146
# Epoch: 127/200 - Train loss 0.522396 - Train Accuracy 0.789062 - Valid Loss 0.517633 - Valid Accuracy 0.848958
# Epoch: 128/200 - Train loss 0.502112 - Train Accuracy 0.794271 - Valid Loss 0.522661 - Valid Accuracy 0.825521
# Epoch: 129/200 - Train loss 0.540219 - Train Accuracy 0.781250 - Valid Loss 0.478659 - Valid Accuracy 0.841146
# Epoch: 130/200 - Train loss 0.539910 - Train Accuracy 0.815104 - Valid Loss 0.502413 - Valid Accuracy 0.848958
# Epoch: 131/200 - Train loss 0.446575 - Train Accuracy 0.861979 - Valid Loss 0.464619 - Valid Accuracy 0.828125
# Epoch: 132/200 - Train loss 0.715569 - Train Accuracy 0.710938 - Valid Loss 0.515565 - Valid Accuracy 0.828125
# Epoch: 133/200 - Train loss 0.568978 - Train Accuracy 0.789062 - Valid Loss 0.454842 - Valid Accuracy 0.841146
# Epoch: 134/200 - Train loss 0.593030 - Train Accuracy 0.799479 - Valid Loss 0.480785 - Valid Accuracy 0.820312
# Epoch: 135/200 - Train loss 0.472865 - Train Accuracy 0.835938 - Valid Loss 0.578699 - Valid Accuracy 0.789062
# Epoch: 136/200 - Train loss 0.477790 - Train Accuracy 0.869792 - Valid Loss 0.483678 - Valid Accuracy 0.791667
# Epoch: 137/200 - Train loss 0.491529 - Train Accuracy 0.815104 - Valid Loss 0.473834 - Valid Accuracy 0.815104
# Epoch: 138/200 - Train loss 0.526415 - Train Accuracy 0.846354 - Valid Loss 0.452067 - Valid Accuracy 0.796875
# Epoch: 139/200 - Train loss 0.489197 - Train Accuracy 0.815104 - Valid Loss 0.475364 - Valid Accuracy 0.812500
# Epoch: 140/200 - Train loss 0.503941 - Train Accuracy 0.815104 - Valid Loss 0.438558 - Valid Accuracy 0.799479
# Epoch: 141/200 - Train loss 0.435833 - Train Accuracy 0.859375 - Valid Loss 0.478544 - Valid Accuracy 0.786458
# Epoch: 142/200 - Train loss 0.592334 - Train Accuracy 0.768229 - Valid Loss 0.408404 - Valid Accuracy 0.864583
# Epoch: 143/200 - Train loss 0.562027 - Train Accuracy 0.794271 - Valid Loss 0.454120 - Valid Accuracy 0.828125
# Epoch: 144/200 - Train loss 0.493875 - Train Accuracy 0.835938 - Valid Loss 0.509728 - Valid Accuracy 0.776042
# Epoch: 145/200 - Train loss 0.460050 - Train Accuracy 0.802083 - Valid Loss 0.401189 - Valid Accuracy 0.875000
# Epoch: 146/200 - Train loss 0.389457 - Train Accuracy 0.875000 - Valid Loss 0.511137 - Valid Accuracy 0.815104
# Epoch: 147/200 - Train loss 0.537250 - Train Accuracy 0.794271 - Valid Loss 0.425842 - Valid Accuracy 0.843750
# Epoch: 148/200 - Train loss 0.442175 - Train Accuracy 0.794271 - Valid Loss 0.526309 - Valid Accuracy 0.760417
# Epoch: 149/200 - Train loss 0.469597 - Train Accuracy 0.833333 - Valid Loss 0.438293 - Valid Accuracy 0.833333
# Epoch: 150/200 - Train loss 0.504476 - Train Accuracy 0.799479 - Valid Loss 0.437869 - Valid Accuracy 0.835938
# Epoch: 151/200 - Train loss 0.660928 - Train Accuracy 0.710938 - Valid Loss 0.615403 - Valid Accuracy 0.791667
# Epoch: 152/200 - Train loss 0.545223 - Train Accuracy 0.765625 - Valid Loss 0.474662 - Valid Accuracy 0.812500
# Epoch: 153/200 - Train loss 0.474892 - Train Accuracy 0.817708 - Valid Loss 0.532074 - Valid Accuracy 0.817708
# Epoch: 154/200 - Train loss 0.428446 - Train Accuracy 0.851562 - Valid Loss 0.559318 - Valid Accuracy 0.812500
# Epoch: 155/200 - Train loss 0.558898 - Train Accuracy 0.765625 - Valid Loss 0.520873 - Valid Accuracy 0.830729
# Epoch: 156/200 - Train loss 0.442201 - Train Accuracy 0.856771 - Valid Loss 0.423373 - Valid Accuracy 0.846354
# Epoch: 157/200 - Train loss 0.369490 - Train Accuracy 0.859375 - Valid Loss 0.405238 - Valid Accuracy 0.872396
# Epoch: 158/200 - Train loss 0.415479 - Train Accuracy 0.843750 - Valid Loss 0.417656 - Valid Accuracy 0.838542
# Epoch: 159/200 - Train loss 0.508235 - Train Accuracy 0.815104 - Valid Loss 0.447027 - Valid Accuracy 0.841146
# Epoch: 160/200 - Train loss 0.490189 - Train Accuracy 0.817708 - Valid Loss 0.399142 - Valid Accuracy 0.869792
# Epoch: 161/200 - Train loss 0.451293 - Train Accuracy 0.828125 - Valid Loss 0.412639 - Valid Accuracy 0.846354
# Epoch: 162/200 - Train loss 0.458697 - Train Accuracy 0.830729 - Valid Loss 0.586705 - Valid Accuracy 0.794271
# Epoch: 163/200 - Train loss 0.404624 - Train Accuracy 0.893229 - Valid Loss 0.477113 - Valid Accuracy 0.828125
# Epoch: 164/200 - Train loss 0.329930 - Train Accuracy 0.895833 - Valid Loss 0.510983 - Valid Accuracy 0.817708
# Epoch: 165/200 - Train loss 0.446722 - Train Accuracy 0.851562 - Valid Loss 0.546821 - Valid Accuracy 0.802083
# Epoch: 166/200 - Train loss 0.448980 - Train Accuracy 0.843750 - Valid Loss 0.510558 - Valid Accuracy 0.854167
# Epoch: 167/200 - Train loss 0.410564 - Train Accuracy 0.848958 - Valid Loss 0.621286 - Valid Accuracy 0.773438
# Epoch: 168/200 - Train loss 0.680408 - Train Accuracy 0.726562 - Valid Loss 0.547024 - Valid Accuracy 0.799479
# Epoch: 169/200 - Train loss 0.342441 - Train Accuracy 0.864583 - Valid Loss 0.563134 - Valid Accuracy 0.820312
# Epoch: 170/200 - Train loss 0.541962 - Train Accuracy 0.791667 - Valid Loss 0.479260 - Valid Accuracy 0.833333
# Epoch: 171/200 - Train loss 0.395786 - Train Accuracy 0.872396 - Valid Loss 0.429480 - Valid Accuracy 0.841146
# Epoch: 172/200 - Train loss 0.442503 - Train Accuracy 0.841146 - Valid Loss 0.376325 - Valid Accuracy 0.872396
# Epoch: 173/200 - Train loss 0.428078 - Train Accuracy 0.851562 - Valid Loss 0.428871 - Valid Accuracy 0.817708
# Epoch: 174/200 - Train loss 0.446905 - Train Accuracy 0.815104 - Valid Loss 0.586210 - Valid Accuracy 0.809896
# Epoch: 175/200 - Train loss 0.461930 - Train Accuracy 0.835938 - Valid Loss 0.397244 - Valid Accuracy 0.875000
# Epoch: 176/200 - Train loss 0.324349 - Train Accuracy 0.851562 - Valid Loss 0.496548 - Valid Accuracy 0.830729
# Epoch: 177/200 - Train loss 0.303089 - Train Accuracy 0.895833 - Valid Loss 0.621236 - Valid Accuracy 0.747396
# Epoch: 178/200 - Train loss 0.359854 - Train Accuracy 0.875000 - Valid Loss 0.541952 - Valid Accuracy 0.770833
# Epoch: 179/200 - Train loss 0.330100 - Train Accuracy 0.882812 - Valid Loss 0.435713 - Valid Accuracy 0.864583
# Epoch: 180/200 - Train loss 0.293769 - Train Accuracy 0.908854 - Valid Loss 0.409214 - Valid Accuracy 0.880208
# Epoch: 181/200 - Train loss 0.353875 - Train Accuracy 0.872396 - Valid Loss 0.417407 - Valid Accuracy 0.843750
# Epoch: 182/200 - Train loss 0.385195 - Train Accuracy 0.864583 - Valid Loss 0.474859 - Valid Accuracy 0.822917
# Epoch: 183/200 - Train loss 0.406009 - Train Accuracy 0.807292 - Valid Loss 0.572831 - Valid Accuracy 0.804688
# Epoch: 184/200 - Train loss 0.271159 - Train Accuracy 0.903646 - Valid Loss 0.544983 - Valid Accuracy 0.809896
# Epoch: 185/200 - Train loss 0.400180 - Train Accuracy 0.822917 - Valid Loss 0.538105 - Valid Accuracy 0.802083
# Epoch: 186/200 - Train loss 0.457285 - Train Accuracy 0.846354 - Valid Loss 0.381339 - Valid Accuracy 0.888021
# Epoch: 187/200 - Train loss 0.387375 - Train Accuracy 0.885417 - Valid Loss 0.367661 - Valid Accuracy 0.869792
# Epoch: 188/200 - Train loss 0.219636 - Train Accuracy 0.934896 - Valid Loss 0.492166 - Valid Accuracy 0.835938
# Epoch: 189/200 - Train loss 0.326917 - Train Accuracy 0.885417 - Valid Loss 0.429808 - Valid Accuracy 0.869792
# Epoch: 190/200 - Train loss 0.290208 - Train Accuracy 0.921875 - Valid Loss 0.413131 - Valid Accuracy 0.851562
# Epoch: 191/200 - Train loss 0.442675 - Train Accuracy 0.854167 - Valid Loss 0.351315 - Valid Accuracy 0.843750
# Epoch: 192/200 - Train loss 0.406246 - Train Accuracy 0.848958 - Valid Loss 0.434869 - Valid Accuracy 0.848958
# Epoch: 193/200 - Train loss 0.327236 - Train Accuracy 0.895833 - Valid Loss 0.467941 - Valid Accuracy 0.841146
# Epoch: 194/200 - Train loss 0.353467 - Train Accuracy 0.856771 - Valid Loss 0.441629 - Valid Accuracy 0.856771
# Epoch: 195/200 - Train loss 0.320942 - Train Accuracy 0.869792 - Valid Loss 0.580951 - Valid Accuracy 0.773438
# Epoch: 196/200 - Train loss 0.401425 - Train Accuracy 0.822917 - Valid Loss 0.439755 - Valid Accuracy 0.820312
# Epoch: 197/200 - Train loss 0.344979 - Train Accuracy 0.869792 - Valid Loss 0.361773 - Valid Accuracy 0.877604
# Epoch: 198/200 - Train loss 0.356268 - Train Accuracy 0.903646 - Valid Loss 0.443325 - Valid Accuracy 0.828125
# Epoch: 199/200 - Train loss 0.310135 - Train Accuracy 0.908854 - Valid Loss 0.436038 - Valid Accuracy 0.843750
# Epoch: 200/200 - Train loss 0.285583 - Train Accuracy 0.893229 - Valid Loss 0.422253 - Valid Accuracy 0.820312

# %% [markdown]
# ### Conclusiones
#
# - Que tipo de transformaciones son mas efectivas en este dataset?
