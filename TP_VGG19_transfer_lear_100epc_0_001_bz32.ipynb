# %% [markdown]
# Librerias a utilizar

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import os

import torch
import torchvision
import torchsummary
import torchmetrics
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# Atributos - definion de clases y size de las imagenes

# %%
CANTIDAD_CLASES = 4
ANCHO_IMAGENES = 256
ALTO_IMAGENES = 256

# %% [markdown]
# Carga de datos con ImageDataGenerator

# %%
from torchvision.models.vgg import VGG19_Weights

weights = VGG19_Weights.IMAGENET1K_V1
transforms = weights.transforms()

# %% [markdown]
# Data aumentation

# %%
aug_data_transforms = torchvision.transforms.Compose([
                        torchvision.transforms.Resize(size=(ANCHO_IMAGENES, ALTO_IMAGENES)),
                        torchvision.transforms.RandomHorizontalFlip(0.5),
                        torchvision.transforms.RandomResizedCrop(size=(ANCHO_IMAGENES, ALTO_IMAGENES), scale=(0.5, 1.0)),
                        torchvision.transforms.ColorJitter(saturation=0.1, hue=0.1),
                        torchvision.transforms.ToTensor()
                      ])

data_transforms = torchvision.transforms.Compose([
                    torchvision.transforms.Resize(size=(ANCHO_IMAGENES, ALTO_IMAGENES)),
                    torchvision.transforms.ToTensor()
                  ])

#train_set = torchvision.datasets.ImageFolder(root='./train', transform=aug_data_transforms)
#valid_set = torchvision.datasets.ImageFolder(root='./validation', transform=data_transforms)
train_set = torchvision.datasets.ImageFolder(root='Dataset_Splitted_/train', transform=aug_data_transforms)
valid_set = torchvision.datasets.ImageFolder(root='Dataset_Splitted_/val', transform=data_transforms)
test_set = torchvision.datasets.ImageFolder(root='Dataset_Splitted_/test', transform=data_transforms)



train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size=32, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=32, shuffle=True)

# %% [markdown]
# Carga de modelo base

# %%
vgg19_model = torchvision.models.vgg19(weights=weights)

vgg19_model.to("cuda")

torchsummary.summary(vgg19_model, input_size=(3, 224, 224))
vgg19_model.modules
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#            Conv2d-17          [-1, 256, 56, 56]         590,080
#              ReLU-18          [-1, 256, 56, 56]               0
#         MaxPool2d-19          [-1, 256, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       1,180,160
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#            Conv2d-24          [-1, 512, 28, 28]       2,359,808
#              ReLU-25          [-1, 512, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       2,359,808
#              ReLU-27          [-1, 512, 28, 28]               0
#         MaxPool2d-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#            Conv2d-31          [-1, 512, 14, 14]       2,359,808
#              ReLU-32          [-1, 512, 14, 14]               0
#            Conv2d-33          [-1, 512, 14, 14]       2,359,808
#              ReLU-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#              ReLU-36          [-1, 512, 14, 14]               0
#         MaxPool2d-37            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [-1, 512, 7, 7]               0
#            Linear-39                 [-1, 4096]     102,764,544
#              ReLU-40                 [-1, 4096]               0
#           Dropout-41                 [-1, 4096]               0
#            Linear-42                 [-1, 4096]      16,781,312
#              ReLU-43                 [-1, 4096]               0
#           Dropout-44                 [-1, 4096]               0
#            Linear-45                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 238.69
# Params size (MB): 548.05
# Estimated Total Size (MB): 787.31
# ----------------------------------------------------------------
# <bound method Module.modules of VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )>

# %% [markdown]
# Congelando capas red base

# %%
for param in vgg19_model.parameters():
    param.requires_grad = False

# %% [markdown]
# Modificand capa base de acuerdo al numero de clases del problema para este caso 4

# %%
last_layer_in_features = vgg19_model.classifier[-1].in_features
vgg19_model.classifier[-1] = torch.nn.Linear(in_features=last_layer_in_features, out_features=CANTIDAD_CLASES)   ### 4 clases

# %%
#verificando el cambio
vgg19_model.modules
# Out:
# <bound method Module.modules of VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )>

# %%
def train(model, optimizer, criterion, metric, data, epochs, tb_writer=None):

    train_loader = data["train"]
    valid_loader = data["valid"]

    train_writer = tb_writer["train"]
    valid_writer = tb_writer["valid"]

    if tb_writer:
        train_writer.add_graph(model, torch.zeros((1, 3, data["image_width"], data["image_height"])))
        valid_writer.add_graph(model, torch.zeros((1, 3, data["image_width"], data["image_height"])))

    if torch.cuda.is_available():
        model.to("cuda")
        metric.to("cuda")

    train_loss = []
    train_acc = []
    valid_loss = []
    valid_acc = []

    for epoch in range(epochs):

        # Pongo el modelo en modo entrenamiento
        model.train()

        epoch_train_loss = 0.0
        epoch_train_accuracy = 0.0

        for train_data, train_target in train_loader:

            if torch.cuda.is_available():
                train_data = train_data.to("cuda")
                train_target = train_target.to("cuda")

            optimizer.zero_grad()
            output = model(train_data.float())
            loss = criterion(output, train_target)
            epoch_train_loss += loss.item()
            loss.backward()
            optimizer.step()

            accuracy = metric(output, train_target)
            epoch_train_accuracy += accuracy.item()

        epoch_train_loss = epoch_train_loss / len(train_loader)
        epoch_train_accuracy = epoch_train_accuracy / len(train_loader)
        train_loss.append(epoch_train_loss)
        train_acc.append(epoch_train_accuracy)

        # Pongo el modelo en modo testeo
        model.eval()

        epoch_valid_loss = 0.0
        epoch_valid_accuracy = 0.0

        for valid_data, valid_target in valid_loader:
            if torch.cuda.is_available():
                valid_data = valid_data.to("cuda")
                valid_target = valid_target.to("cuda")

            output = model(valid_data.float())
            epoch_valid_loss += criterion(output, valid_target).item()
            epoch_valid_accuracy += metric(output, valid_target).item()

        epoch_valid_loss = epoch_valid_loss / len(valid_loader)
        epoch_valid_accuracy = epoch_valid_accuracy / len(valid_loader)
        valid_loss.append(epoch_valid_loss)
        valid_acc.append(epoch_valid_accuracy)

        print("Epoch: {}/{} - Train loss {:.6f} - Train Accuracy {:.6f} - Valid Loss {:.6f} - Valid Accuracy {:.6f}".format(
        epoch+1, epochs, epoch_train_loss, epoch_train_accuracy, epoch_valid_loss, epoch_valid_accuracy))

        if tb_writer:
            train_writer.add_scalar("loss", epoch_train_loss, epoch)
            valid_writer.add_scalar("loss", epoch_valid_loss, epoch)
            train_writer.add_scalar("accuracy", epoch_train_accuracy, epoch)
            valid_writer.add_scalar("accuracy", epoch_valid_accuracy, epoch)
            train_writer.flush()
            valid_writer.flush()

    history = {}
    history["train_loss"] = train_loss
    history["train_acc"] = train_acc
    history["valid_loss"] = valid_loss
    history["valid_acc"] = valid_acc

    return history

# %%
#verificar si esta activa la gpu
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# entrenamiento

# %%
Epochs=100
learning_rate= 0.001
optimizer = torch.optim.Adam(vgg19_model.parameters(), lr=learning_rate)
loss = torch.nn.CrossEntropyLoss()
metric = torchmetrics.Accuracy(task='multiclass', num_classes=CANTIDAD_CLASES)
data = {"train": train_loader, "valid": valid_loader, "image_width": ANCHO_IMAGENES, "image_height": ALTO_IMAGENES}
writer = {"train": SummaryWriter(log_dir="transfer_learning_vgg/train"),
          "valid": SummaryWriter(log_dir="transfer_learning_vgg/valid")}

history = train(vgg19_model.to("cpu"),
                optimizer,
                loss,
                metric,
                data,
                Epochs,
                writer)

fig, axs = plt.subplots(2, 1, figsize=(10, 10))

axs[0].plot(history["train_loss"])
axs[0].plot(history["valid_loss"])
axs[0].title.set_text('Error de Entrenamiento vs Validación')
axs[0].legend(['Train', 'Valid'])

axs[1].plot(history["train_acc"])
axs[1].plot(history["valid_acc"])
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación')
axs[1].legend(['Train', 'Valid'])
# Out:
# Epoch: 1/100 - Train loss 0.537418 - Train Accuracy 0.796488 - Valid Loss 0.373106 - Valid Accuracy 0.879464
# Epoch: 2/100 - Train loss 0.366371 - Train Accuracy 0.862679 - Valid Loss 0.441439 - Valid Accuracy 0.828125
# Epoch: 3/100 - Train loss 0.346949 - Train Accuracy 0.866488 - Valid Loss 0.281431 - Valid Accuracy 0.899554
# Epoch: 4/100 - Train loss 0.325792 - Train Accuracy 0.874881 - Valid Loss 0.282439 - Valid Accuracy 0.892857
# Epoch: 5/100 - Train loss 0.304292 - Train Accuracy 0.882262 - Valid Loss 0.305707 - Valid Accuracy 0.904018
# Epoch: 6/100 - Train loss 0.309538 - Train Accuracy 0.879107 - Valid Loss 0.298256 - Valid Accuracy 0.908482
# Epoch: 7/100 - Train loss 0.298682 - Train Accuracy 0.878452 - Valid Loss 0.357882 - Valid Accuracy 0.821429
# Epoch: 8/100 - Train loss 0.301015 - Train Accuracy 0.878333 - Valid Loss 0.283986 - Valid Accuracy 0.899554
# Epoch: 9/100 - Train loss 0.311459 - Train Accuracy 0.876667 - Valid Loss 0.261408 - Valid Accuracy 0.901786
# Epoch: 10/100 - Train loss 0.281843 - Train Accuracy 0.894583 - Valid Loss 0.521526 - Valid Accuracy 0.832589
# Epoch: 11/100 - Train loss 0.297963 - Train Accuracy 0.877798 - Valid Loss 0.261802 - Valid Accuracy 0.890625
# Epoch: 12/100 - Train loss 0.282031 - Train Accuracy 0.885179 - Valid Loss 0.253308 - Valid Accuracy 0.895089
# Epoch: 13/100 - Train loss 0.284568 - Train Accuracy 0.881071 - Valid Loss 0.445465 - Valid Accuracy 0.834821
# Epoch: 14/100 - Train loss 0.288901 - Train Accuracy 0.884881 - Valid Loss 0.254167 - Valid Accuracy 0.886161
# Epoch: 15/100 - Train loss 0.293880 - Train Accuracy 0.884464 - Valid Loss 0.255968 - Valid Accuracy 0.906250
# Epoch: 16/100 - Train loss 0.293958 - Train Accuracy 0.885060 - Valid Loss 0.380637 - Valid Accuracy 0.837054
# Epoch: 17/100 - Train loss 0.287251 - Train Accuracy 0.884345 - Valid Loss 0.241620 - Valid Accuracy 0.908482
# Epoch: 18/100 - Train loss 0.272966 - Train Accuracy 0.891310 - Valid Loss 0.272441 - Valid Accuracy 0.881696
# Epoch: 19/100 - Train loss 0.295592 - Train Accuracy 0.884167 - Valid Loss 0.248574 - Valid Accuracy 0.910714
# Epoch: 20/100 - Train loss 0.288179 - Train Accuracy 0.884524 - Valid Loss 0.247499 - Valid Accuracy 0.901786
# Epoch: 21/100 - Train loss 0.298822 - Train Accuracy 0.882500 - Valid Loss 0.264137 - Valid Accuracy 0.897321
# Epoch: 22/100 - Train loss 0.284183 - Train Accuracy 0.894286 - Valid Loss 0.251845 - Valid Accuracy 0.908482
# Epoch: 23/100 - Train loss 0.289089 - Train Accuracy 0.884881 - Valid Loss 0.514540 - Valid Accuracy 0.805804
# Epoch: 24/100 - Train loss 0.267352 - Train Accuracy 0.899345 - Valid Loss 0.292219 - Valid Accuracy 0.904018
# Epoch: 25/100 - Train loss 0.272283 - Train Accuracy 0.894464 - Valid Loss 0.262066 - Valid Accuracy 0.906250
# Epoch: 26/100 - Train loss 0.269971 - Train Accuracy 0.893988 - Valid Loss 0.251012 - Valid Accuracy 0.908482
# Epoch: 27/100 - Train loss 0.279645 - Train Accuracy 0.897262 - Valid Loss 0.291314 - Valid Accuracy 0.904018
# Epoch: 28/100 - Train loss 0.266788 - Train Accuracy 0.895952 - Valid Loss 0.249845 - Valid Accuracy 0.906250
# Epoch: 29/100 - Train loss 0.271633 - Train Accuracy 0.898512 - Valid Loss 0.252672 - Valid Accuracy 0.910714
# Epoch: 30/100 - Train loss 0.286344 - Train Accuracy 0.891190 - Valid Loss 0.252539 - Valid Accuracy 0.901786
# Epoch: 31/100 - Train loss 0.262851 - Train Accuracy 0.901190 - Valid Loss 0.249567 - Valid Accuracy 0.912946
# Epoch: 32/100 - Train loss 0.278049 - Train Accuracy 0.891310 - Valid Loss 0.267584 - Valid Accuracy 0.901786
# Epoch: 33/100 - Train loss 0.274051 - Train Accuracy 0.891012 - Valid Loss 0.263090 - Valid Accuracy 0.910714
# Epoch: 34/100 - Train loss 0.278539 - Train Accuracy 0.892321 - Valid Loss 0.358509 - Valid Accuracy 0.825893
# Epoch: 35/100 - Train loss 0.271720 - Train Accuracy 0.893512 - Valid Loss 0.238684 - Valid Accuracy 0.917411
# Epoch: 36/100 - Train loss 0.270185 - Train Accuracy 0.889286 - Valid Loss 0.269711 - Valid Accuracy 0.912946
# Epoch: 37/100 - Train loss 0.263744 - Train Accuracy 0.898452 - Valid Loss 0.250959 - Valid Accuracy 0.899554
# Epoch: 38/100 - Train loss 0.269633 - Train Accuracy 0.892679 - Valid Loss 0.240164 - Valid Accuracy 0.912946
# Epoch: 39/100 - Train loss 0.273760 - Train Accuracy 0.892202 - Valid Loss 0.240905 - Valid Accuracy 0.910714
# Epoch: 40/100 - Train loss 0.284230 - Train Accuracy 0.888810 - Valid Loss 0.247624 - Valid Accuracy 0.917411
# Epoch: 41/100 - Train loss 0.265450 - Train Accuracy 0.893929 - Valid Loss 0.266493 - Valid Accuracy 0.912946
# Epoch: 42/100 - Train loss 0.276031 - Train Accuracy 0.896250 - Valid Loss 0.244807 - Valid Accuracy 0.906250
# Epoch: 43/100 - Train loss 0.277603 - Train Accuracy 0.891131 - Valid Loss 0.283884 - Valid Accuracy 0.881696
# Epoch: 44/100 - Train loss 0.258685 - Train Accuracy 0.893095 - Valid Loss 0.246452 - Valid Accuracy 0.906250
# Epoch: 45/100 - Train loss 0.276937 - Train Accuracy 0.887381 - Valid Loss 0.237645 - Valid Accuracy 0.910714
# Epoch: 46/100 - Train loss 0.269727 - Train Accuracy 0.894345 - Valid Loss 0.258554 - Valid Accuracy 0.899554
# Epoch: 47/100 - Train loss 0.278100 - Train Accuracy 0.889405 - Valid Loss 0.251464 - Valid Accuracy 0.910714
# Epoch: 48/100 - Train loss 0.264035 - Train Accuracy 0.895893 - Valid Loss 0.236657 - Valid Accuracy 0.906250
# Epoch: 49/100 - Train loss 0.283653 - Train Accuracy 0.885774 - Valid Loss 0.241966 - Valid Accuracy 0.904018
# Epoch: 50/100 - Train loss 0.249982 - Train Accuracy 0.902917 - Valid Loss 0.255169 - Valid Accuracy 0.919643
# Epoch: 51/100 - Train loss 0.273330 - Train Accuracy 0.894286 - Valid Loss 0.233785 - Valid Accuracy 0.912946
# Epoch: 52/100 - Train loss 0.263227 - Train Accuracy 0.898690 - Valid Loss 0.247409 - Valid Accuracy 0.906250
# Epoch: 53/100 - Train loss 0.284632 - Train Accuracy 0.891488 - Valid Loss 0.281055 - Valid Accuracy 0.890625
# Epoch: 54/100 - Train loss 0.281550 - Train Accuracy 0.892143 - Valid Loss 0.241338 - Valid Accuracy 0.899554
# Epoch: 55/100 - Train loss 0.251152 - Train Accuracy 0.901012 - Valid Loss 0.285430 - Valid Accuracy 0.912946
# Epoch: 56/100 - Train loss 0.260678 - Train Accuracy 0.895476 - Valid Loss 0.312181 - Valid Accuracy 0.832589
# Epoch: 57/100 - Train loss 0.280479 - Train Accuracy 0.890595 - Valid Loss 0.344298 - Valid Accuracy 0.825893
# Epoch: 58/100 - Train loss 0.265092 - Train Accuracy 0.900357 - Valid Loss 0.301283 - Valid Accuracy 0.834821
# Epoch: 59/100 - Train loss 0.270032 - Train Accuracy 0.894464 - Valid Loss 0.241923 - Valid Accuracy 0.919643
# Epoch: 60/100 - Train loss 0.274974 - Train Accuracy 0.895774 - Valid Loss 0.247405 - Valid Accuracy 0.908482
# Epoch: 61/100 - Train loss 0.267863 - Train Accuracy 0.894464 - Valid Loss 0.250868 - Valid Accuracy 0.919643
# Epoch: 62/100 - Train loss 0.265734 - Train Accuracy 0.896726 - Valid Loss 0.255950 - Valid Accuracy 0.917411
# Epoch: 63/100 - Train loss 0.267604 - Train Accuracy 0.896310 - Valid Loss 0.293267 - Valid Accuracy 0.910714
# Epoch: 64/100 - Train loss 0.273753 - Train Accuracy 0.893869 - Valid Loss 0.237113 - Valid Accuracy 0.901786
# Epoch: 65/100 - Train loss 0.261130 - Train Accuracy 0.897083 - Valid Loss 0.221352 - Valid Accuracy 0.912946
# Epoch: 66/100 - Train loss 0.269437 - Train Accuracy 0.893095 - Valid Loss 0.260673 - Valid Accuracy 0.910714
# Epoch: 67/100 - Train loss 0.275860 - Train Accuracy 0.897560 - Valid Loss 0.299606 - Valid Accuracy 0.904018
# Epoch: 68/100 - Train loss 0.265862 - Train Accuracy 0.898214 - Valid Loss 0.339268 - Valid Accuracy 0.841518
# Epoch: 69/100 - Train loss 0.278371 - Train Accuracy 0.893095 - Valid Loss 0.281414 - Valid Accuracy 0.881696
# Epoch: 70/100 - Train loss 0.270188 - Train Accuracy 0.888690 - Valid Loss 0.245618 - Valid Accuracy 0.912946
# Epoch: 71/100 - Train loss 0.275105 - Train Accuracy 0.892798 - Valid Loss 0.246351 - Valid Accuracy 0.912946
# Epoch: 72/100 - Train loss 0.271871 - Train Accuracy 0.897143 - Valid Loss 0.249220 - Valid Accuracy 0.910714
# Epoch: 73/100 - Train loss 0.268133 - Train Accuracy 0.891488 - Valid Loss 0.238645 - Valid Accuracy 0.906250
# Epoch: 74/100 - Train loss 0.275569 - Train Accuracy 0.888452 - Valid Loss 0.252483 - Valid Accuracy 0.910714
# Epoch: 75/100 - Train loss 0.270508 - Train Accuracy 0.904167 - Valid Loss 0.606416 - Valid Accuracy 0.828125
# Epoch: 76/100 - Train loss 0.269135 - Train Accuracy 0.894643 - Valid Loss 0.276343 - Valid Accuracy 0.888393
# Epoch: 77/100 - Train loss 0.271325 - Train Accuracy 0.893214 - Valid Loss 0.258841 - Valid Accuracy 0.906250
# Epoch: 78/100 - Train loss 0.252216 - Train Accuracy 0.902202 - Valid Loss 0.290728 - Valid Accuracy 0.908482
# Epoch: 79/100 - Train loss 0.279417 - Train Accuracy 0.892500 - Valid Loss 0.268073 - Valid Accuracy 0.904018
# Epoch: 80/100 - Train loss 0.268772 - Train Accuracy 0.898274 - Valid Loss 0.258756 - Valid Accuracy 0.910714
# Epoch: 81/100 - Train loss 0.273415 - Train Accuracy 0.895476 - Valid Loss 0.406517 - Valid Accuracy 0.819196
# Epoch: 82/100 - Train loss 0.256302 - Train Accuracy 0.905060 - Valid Loss 0.248504 - Valid Accuracy 0.912946
# Epoch: 83/100 - Train loss 0.263183 - Train Accuracy 0.899286 - Valid Loss 0.251231 - Valid Accuracy 0.906250
# Epoch: 84/100 - Train loss 0.258508 - Train Accuracy 0.900536 - Valid Loss 0.250442 - Valid Accuracy 0.908482
# Epoch: 85/100 - Train loss 0.270858 - Train Accuracy 0.895119 - Valid Loss 0.252760 - Valid Accuracy 0.904018
# Epoch: 86/100 - Train loss 0.268912 - Train Accuracy 0.897143 - Valid Loss 0.286515 - Valid Accuracy 0.881696
# Epoch: 87/100 - Train loss 0.273943 - Train Accuracy 0.895119 - Valid Loss 0.261727 - Valid Accuracy 0.897321
# Epoch: 88/100 - Train loss 0.264813 - Train Accuracy 0.899405 - Valid Loss 0.253242 - Valid Accuracy 0.908482
# Epoch: 89/100 - Train loss 0.268441 - Train Accuracy 0.892560 - Valid Loss 0.255364 - Valid Accuracy 0.901786
# Epoch: 90/100 - Train loss 0.267469 - Train Accuracy 0.892857 - Valid Loss 0.280116 - Valid Accuracy 0.917411
# Epoch: 91/100 - Train loss 0.282379 - Train Accuracy 0.890536 - Valid Loss 0.257070 - Valid Accuracy 0.908482
# Epoch: 92/100 - Train loss 0.254858 - Train Accuracy 0.901012 - Valid Loss 0.248481 - Valid Accuracy 0.906250
# Epoch: 93/100 - Train loss 0.272532 - Train Accuracy 0.893095 - Valid Loss 0.287314 - Valid Accuracy 0.883929
# Epoch: 94/100 - Train loss 0.273947 - Train Accuracy 0.894524 - Valid Loss 0.261256 - Valid Accuracy 0.906250
# Epoch: 95/100 - Train loss 0.261318 - Train Accuracy 0.901131 - Valid Loss 0.246859 - Valid Accuracy 0.904018
# Epoch: 96/100 - Train loss 0.263349 - Train Accuracy 0.903810 - Valid Loss 0.488219 - Valid Accuracy 0.832589
# Epoch: 97/100 - Train loss 0.265194 - Train Accuracy 0.902024 - Valid Loss 0.239444 - Valid Accuracy 0.917411
# Epoch: 98/100 - Train loss 0.254349 - Train Accuracy 0.905238 - Valid Loss 0.254342 - Valid Accuracy 0.904018
# Epoch: 99/100 - Train loss 0.263818 - Train Accuracy 0.897917 - Valid Loss 0.256893 - Valid Accuracy 0.897321
# Epoch: 100/100 - Train loss 0.265015 - Train Accuracy 0.900833 - Valid Loss 0.268156 - Valid Accuracy 0.897321

# %%
#funcion para calcular accuracy
def accuracy(model, loader):
    num_correct = 0
    num_total = 0
    model.eval()
    model = model.to(device=device)
    with torch.no_grad():
        for (xi, yi) in loader:
            xi = xi.to(device=device, dtype = torch.float32)
            yi = yi.to(device=device, dtype = torch.long)
            scores = model(xi) # mb_size, 10
            _, pred = scores.max(dim=1) #pred shape (mb_size )
            num_correct += (pred == yi).sum() # pred shape (mb_size), yi shape (mb_size, 1)
            num_total += pred.size(0)
        return float(num_correct)/num_total

# %%
ac_train=accuracy(vgg19_model, train_loader)
ac_val=accuracy(vgg19_model, valid_loader) 
ac_test=accuracy(vgg19_model, test_loader)

print(f"Accuracy Training {ac_train}")
print(f"Accuracy Validation {ac_val}")
print(f"Accuracy Testing {ac_test}")
# Out:
# Accuracy Training 0.942652329749104
# Accuracy Validation 0.8896882494004796
# Accuracy Testing 0.8865248226950354

# %%
PATH = 'Modelos_entrenados/vgg19v1.pt'
#Modelos_entrenados
torch.save(vgg19_model.state_dict(), PATH)
